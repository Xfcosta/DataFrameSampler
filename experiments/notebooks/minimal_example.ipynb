# %% [markdown]
# # Minimal DataFrameSampler example
#
# Load a small tabular dataset, inspect it, fit `DataFrameSampler`, and inspect generated rows.

# %%
from sklearn.datasets import fetch_openml

from dataframe_sampler import DataFrameSampler

# %%
adult = fetch_openml("adult", version=2, as_frame=True, parser="auto")
dataframe = adult.frame[
    [
        "age",
        "workclass",
        "education",
        "marital-status",
        "occupation",
        "hours-per-week",
        "class",
    ]
].dropna().sample(n=100, random_state=42).reset_index(drop=True)

dataframe.head()
# Out:
#    age     workclass  education      marital-status       occupation  \
# 0   47     Local-gov  Bachelors  Married-civ-spouse  Protective-serv
# 1   28       Private  Bachelors  Married-civ-spouse            Sales
# 2   38  Self-emp-inc  Bachelors  Married-civ-spouse     Craft-repair
# 3   37     Local-gov  Bachelors       Never-married   Prof-specialty
# 4   34       Private    HS-grad       Never-married     Craft-repair
#
#    hours-per-week  class
# 0              40  <=50K
# 1              40  <=50K
# 2              50   >50K
# 3              45  <=50K
# 4              40  <=50K

# %%
sampler = DataFrameSampler().fit(dataframe)
generated = sampler.generate(n_samples=10)

generated.head()
# Out:
#    age         workclass  education      marital-status       occupation  \
# 0   21  Self-emp-not-inc       10th       Never-married  Farming-fishing
# 1   62           Private  Bachelors  Married-civ-spouse            Sales
# 2   30       Federal-gov       10th           Separated   Prof-specialty
# 3   46           Private    HS-grad       Never-married     Craft-repair
# 4   61         Local-gov    HS-grad  Married-civ-spouse    Other-service
#
#    hours-per-week  class
# 0              21  <=50K
# 1              50  <=50K
# 2              50  <=50K
# 3              40   >50K
# 4              40  <=50K
